# %%
import pandas as pd

# %%
import numpy as np

# %%
exam_data = {'nom': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'note': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'tentatives': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualifié': ['oui', 'non', 'oui', 'non', 'non', 'oui', 'oui', 'non', 'non', 'oui']}

étiquettes = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
dframe = pd.DataFrame(exam_data)
print(dframe)
# Out:
#          nom  note  tentatives qualifié
# 0  Anastasia  12.5           1      oui
# 1       Dima   9.0           3      non
# 2  Katherine  16.5           2      oui
# 3      James   NaN           3      non
# 4      Emily   9.0           2      non
# 5    Michael  20.0           3      oui
# 6    Matthew  14.5           1      oui
# 7      Laura   NaN           1      non
# 8      Kevin   8.0           2      non
# 9      Jonas  19.0           1      oui

# %%
dframe.head(3)
# Out:
#          nom  note  tentatives qualifié
# 0  Anastasia  12.5           1      oui
# 1       Dima   9.0           3      non
# 2  Katherine  16.5           2      oui

# %%
dframe.dropna()
# Out:
#          nom  note  tentatives qualifié
# 0  Anastasia  12.5           1      oui
# 1       Dima   9.0           3      non
# 2  Katherine  16.5           2      oui
# 4      Emily   9.0           2      non
# 5    Michael  20.0           3      oui
# 6    Matthew  14.5           1      oui
# 8      Kevin   8.0           2      non
# 9      Jonas  19.0           1      oui

# %%
dframe[["qualifié","tentatives"]]
# Out:
#   qualifié  tentatives
# 0      oui           1
# 1      non           3
# 2      oui           2
# 3      non           3
# 4      non           2
# 5      oui           3
# 6      oui           1
# 7      non           1
# 8      non           2
# 9      oui           1

# %%
dframe[["qualifié","nom","note"]]
# Out:
#   qualifié        nom  note
# 0      oui  Anastasia  12.5
# 1      non       Dima   9.0
# 2      oui  Katherine  16.5
# 3      non      James   NaN
# 4      non      Emily   9.0
# 5      oui    Michael  20.0
# 6      oui    Matthew  14.5
# 7      non      Laura   NaN
# 8      non      Kevin   8.0
# 9      oui      Jonas  19.0

# %%
dframe["succès"] = (dframe["note"] > 10).astype(int)
dframe
# Out:
#          nom  note  tentatives qualifié  succès
# 0  Anastasia  12.5           1      oui       1
# 1       Dima   9.0           3      non       0
# 2  Katherine  16.5           2      oui       1
# 3      James   NaN           3      non       0
# 4      Emily   9.0           2      non       0
# 5    Michael  20.0           3      oui       1
# 6    Matthew  14.5           1      oui       1
# 7      Laura   NaN           1      non       0
# 8      Kevin   8.0           2      non       0
# 9      Jonas  19.0           1      oui       1

# %%
# Out:
# {'nom': ['Anastasia',
#   'Dima',
#   'Katherine',
#   'James',
#   'Emily',
#   'Michael',
#   'Matthew',
#   'Laura',
#   'Kevin',
#   'Jonas'],
#  'note': [12.5, 9, 16.5, nan, 9, 20, 14.5, nan, 8, 19],
#  'tentatives': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#  'qualifié': ['oui',
#   'non',
#   'oui',
#   'non',
#   'non',
#   'oui',
#   'oui',
#   'non',
#   'non',
#   'oui']}

# %%
dframe.to_csv("mes_donnes")
dframe
# Out:
#          nom  note  tentatives qualifié  succès
# 0  Anastasia  12.5           1      oui       1
# 1       Dima   9.0           3      non       0
# 2  Katherine  16.5           2      oui       1
# 3      James   NaN           3      non       0
# 4      Emily   9.0           2      non       0
# 5    Michael  20.0           3      oui       1
# 6    Matthew  14.5           1      oui       1
# 7      Laura   NaN           1      non       0
# 8      Kevin   8.0           2      non       0
# 9      Jonas  19.0           1      oui       1

# %%
dframe.to_csv("k")

# %%
k={"nom":"Surech","note":15.5,"tentatives":1,"qualification":"oui"}
k=pd.DataFrame([k], index = ["k"])
pd.concat([k,dframe])
# Out:
#          nom  note  tentatives qualification qualifié  succès
# k     Surech  15.5           1           oui      NaN     NaN
# 0  Anastasia  12.5           1           NaN      oui     1.0
# 1       Dima   9.0           3           NaN      non     0.0
# 2  Katherine  16.5           2           NaN      oui     1.0
# 3      James   NaN           3           NaN      non     0.0
# 4      Emily   9.0           2           NaN      non     0.0
# 5    Michael  20.0           3           NaN      oui     1.0
# 6    Matthew  14.5           1           NaN      oui     1.0
# 7      Laura   NaN           1           NaN      non     0.0
# 8      Kevin   8.0           2           NaN      non     0.0
# 9      Jonas  19.0           1           NaN      oui     1.0

# %%
pd.DataFrame([k], index = ["k"])
# Out:
#       nom  note  tentatives qualification
# k  Surech  15.5           1           oui
